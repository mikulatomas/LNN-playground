# %%
from itertools import chain
from lnn import Predicate, Variable, Exists, Implies, And, ForAll, Model, Fact, World

# %% [markdown]
# ![Hierarchy](https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/Quadrilateral_hierarchy_svg.svg/629px-Quadrilateral_hierarchy_svg.svg.png)

# %%
entities = [
    "3-sides-equal trapezoid",
    "bicentric",
    "complex",
    "concave",
    "convex",
    "cyclic",
    "isosceles trapezoid",
    "kite",
    "parallelogram",
    "quadrilateral",
    "rectangle",
    "rhombus",
    "right-angled trapezoid",
    "simple",
    "square",
    "tangential",
    "trapezoid",
]

entity_relationships = [
    ("square", "rhombus"),
    ("square", "bicentric"),
    ("square", "rectangle"),
    ("square", "3-sides-equal trapezoid"),
    ("rhombus", "kite"),
    ("rhombus", "parallelogram"),
    ("bicentric", "tangential"),
    ("bicentric", "cyclic"),
    ("rectangle", "parallelogram"),
    ("rectangle", "right-angled trapezoid"),
    ("rectangle", "isosceles trapezoid"),
    ("3-sides-equal trapezoid", "isosceles trapezoid"),
    ("kite", "tangential"),
    ("parallelogram", "trapezoid"),
    ("right-angled trapezoid", "trapezoid"),
    ("isosceles trapezoid", "trapezoid"),
    ("tangential", "convex"),
    ("trapezoid", "convex"),
    ("cyclic", "convex"),
    ("convex", "simple"),
    ("concave", "simple"),
    ("complex", "quadrilateral"),
]

for entity1, entity2 in entity_relationships:
    assert entity1 in entities
    assert entity2 in entities

properties = [
    # quadrilateral
    "foursided",
    # simple
    "not-self_intersecting", # negation?
    # complex
    "self-intersecting",
    # convex
    "no-reflex-interior-angle",
    # concave
    "atleast-one-reflex-interior-angle", # negation?
    # tangential
    "sides-are-tangents-to-inscribed-circle",
    # trapezoid
    "atleast-one-pair-opposite-sides-parallel",
    # cyclic
    "four-verticles-on-circumscribed-circle",
    # kite
    "two-pairs-adjacent-sides-equal-length",
    # parallelogram
    "two-pairs-opposite-sides-parallel",
    # right angled trapezoid
    "two-adjacent-right-angles",
    # isosceles trapezoid
    "base-angles-are-same",
    # rhombus
    "all-sides-equal-length",
    # rectangle
    "all-right-angles",
    # 3-sides-equal trapezoid
    "atleast-three-congruent-sides"
]

entity_properties = [
    ("quadrilateral", "foursided"),
    ("simple", "not-self_intersecting"),
    ("complex", "self-intersecting"),
    ("convex", "no-reflex-interior-angle"),
    ("concave", "atleast-one-reflex-interior-angle"),
    ("tangential", "sides-are-tangents-to-inscribed-circle"),
    ("trapezoid", "atleast-one-pair-opposite-sides-parallel"),
    ("cyclic", "four-verticles-on-circumscribed-circle"),
    ("kite", "two-pairs-adjacent-sides-equal-length"),
    ("parallelogram", "two-pairs-opposite-sides-parallel"),
    ("right-angled trapezoid", "two-adjacent-right-angles"),
    ("isosceles trapezoid", "base-angles-are-same"),
    ("rhombus", "all-sides-equal-length"),
    ("rectangle", "all-right-angles"),
    ("3-sides-equal trapezoid", "atleast-three-congruent-sides")
]

for entity, property in entity_properties:
    assert entity in entities
    assert property in properties

# %%
# gegnerate one object of all entity types
facts = dict([(entity, [f"{entity}1"]) for entity in entities])
facts
# Out:
# {'3-sides-equal trapezoid': ['3-sides-equal trapezoid1'],
#  'bicentric': ['bicentric1'],
#  'complex': ['complex1'],
#  'concave': ['concave1'],
#  'convex': ['convex1'],
#  'cyclic': ['cyclic1'],
#  'isosceles trapezoid': ['isosceles trapezoid1'],
#  'kite': ['kite1'],
#  'parallelogram': ['parallelogram1'],
#  'quadrilateral': ['quadrilateral1'],
#  'rectangle': ['rectangle1'],
#  'rhombus': ['rhombus1'],
#  'right-angled trapezoid': ['right-angled trapezoid1'],
#  'simple': ['simple1'],
#  'square': ['square1'],
#  'tangential': ['tangential1'],
#  'trapezoid': ['trapezoid1']}

# %%
model = Model()

x = Variable("x")

# parsing predicates
for predicate in chain(entities, properties):
    model[predicate] = Predicate(name=predicate)

# %%
# parsing axioms in Implication and ForAll shape
axioms = [
    ForAll(
        x,
        Implies(model[p1](x), model[p2](x), name=f"{p1}_{p2}"),
        name=f"all-{p1}_{p2}",
        world=World.AXIOM,
    )
    for p1, p2 in chain(entity_relationships, entity_properties)
]

model.add_formulae(*axioms)

# %%
# parsing facts
model.add_facts(
    {entity: {name: Fact.TRUE for name in names} for entity, names in facts.items()}
)

# %%
queries = [
    Exists(x, model["foursided"](x), name="foursided_objects"),
    Exists(
        x,
        And(model["all-right-angles"](x), model["all-sides-equal-length"](x)),
        name="all-right-angles-and-all-sides-equal-length",
    )
]

model.add_formulae(*queries)

# %%
steps, facts_inferred = model.infer()

for query in queries:
    print(f"Query {query.name} result:")
    print(model[query.name].true_groundings)
# Out:
# Query foursided_objects result:
# {'quadrilateral1', 'complex1'}
# Query all-right-angles-and-all-sides-equal-length result:
# {'square1'}

# %%
model.print()
# Out:
# ***************************************************************************
#                                 LNN Model
#
# OPEN   Exists: all-right-angles-and-all-sides-equal-length (x)          TRUE (1.0, 1.0)
#
# OPEN   And: And_2(x)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Exists: foursided_objects (x)                        TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-3-sides-equal trapezoid_atleast-three-congruent-sides (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: 3-sides-equal trapezoid_atleast-three-congruent-sides(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-rectangle_all-right-angles (x)           TRUE (1.0, 1.0)
#
# OPEN   Implies: rectangle_all-right-angles(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-rhombus_all-sides-equal-length (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: rhombus_all-sides-equal-length(x)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-isosceles trapezoid_base-angles-are-same (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: isosceles trapezoid_base-angles-are-same(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-right-angled trapezoid_two-adjacent-right-angles (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: right-angled trapezoid_two-adjacent-right-angles(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-parallelogram_two-pairs-opposite-sides-parallel (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: parallelogram_two-pairs-opposite-sides-parallel(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-kite_two-pairs-adjacent-sides-equal-length (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: kite_two-pairs-adjacent-sides-equal-length(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-cyclic_four-verticles-on-circumscribed-circle (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: cyclic_four-verticles-on-circumscribed-circle(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-trapezoid_atleast-one-pair-opposite-sides-parallel (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: trapezoid_atleast-one-pair-opposite-sides-parallel(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-tangential_sides-are-tangents-to-inscribed-circle (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: tangential_sides-are-tangents-to-inscribed-circle(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-concave_atleast-one-reflex-interior-angle (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: concave_atleast-one-reflex-interior-angle(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-convex_no-reflex-interior-angle (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: convex_no-reflex-interior-angle(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-complex_self-intersecting (x)            TRUE (1.0, 1.0)
#
# OPEN   Implies: complex_self-intersecting(x)
# 'quadrilateral1'                                            TRUE (1.0, 1.0)
# 'complex1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-simple_not-self_intersecting (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: simple_not-self_intersecting(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-quadrilateral_foursided (x)              TRUE (1.0, 1.0)
#
# OPEN   Implies: quadrilateral_foursided(x)
# 'quadrilateral1'                                            TRUE (1.0, 1.0)
# 'complex1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-complex_quadrilateral (x)                TRUE (1.0, 1.0)
#
# OPEN   Implies: complex_quadrilateral(x)
# 'quadrilateral1'                                            TRUE (1.0, 1.0)
# 'complex1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-concave_simple (x)                       TRUE (1.0, 1.0)
#
# OPEN   Implies: concave_simple(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-convex_simple (x)                        TRUE (1.0, 1.0)
#
# OPEN   Implies: convex_simple(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-cyclic_convex (x)                        TRUE (1.0, 1.0)
#
# OPEN   Implies: cyclic_convex(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-trapezoid_convex (x)                     TRUE (1.0, 1.0)
#
# OPEN   Implies: trapezoid_convex(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-tangential_convex (x)                    TRUE (1.0, 1.0)
#
# OPEN   Implies: tangential_convex(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-isosceles trapezoid_trapezoid (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: isosceles trapezoid_trapezoid(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-right-angled trapezoid_trapezoid (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: right-angled trapezoid_trapezoid(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-parallelogram_trapezoid (x)              TRUE (1.0, 1.0)
#
# OPEN   Implies: parallelogram_trapezoid(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-kite_tangential (x)                      TRUE (1.0, 1.0)
#
# OPEN   Implies: kite_tangential(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-3-sides-equal trapezoid_isosceles trapezoid (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: 3-sides-equal trapezoid_isosceles trapezoid(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-rectangle_isosceles trapezoid (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: rectangle_isosceles trapezoid(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-rectangle_right-angled trapezoid (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: rectangle_right-angled trapezoid(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-rectangle_parallelogram (x)              TRUE (1.0, 1.0)
#
# OPEN   Implies: rectangle_parallelogram(x)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-bicentric_cyclic (x)                     TRUE (1.0, 1.0)
#
# OPEN   Implies: bicentric_cyclic(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-bicentric_tangential (x)                 TRUE (1.0, 1.0)
#
# OPEN   Implies: bicentric_tangential(x)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-rhombus_parallelogram (x)                TRUE (1.0, 1.0)
#
# OPEN   Implies: rhombus_parallelogram(x)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-rhombus_kite (x)                         TRUE (1.0, 1.0)
#
# OPEN   Implies: rhombus_kite(x)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-square_3-sides-equal trapezoid (x)          TRUE (1.0, 1.0)
#
# OPEN   Implies: square_3-sides-equal trapezoid(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-square_rectangle (x)                     TRUE (1.0, 1.0)
#
# OPEN   Implies: square_rectangle(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-square_bicentric (x)                     TRUE (1.0, 1.0)
#
# OPEN   Implies: square_bicentric(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# AXIOM  ForAll: all-square_rhombus (x)                       TRUE (1.0, 1.0)
#
# OPEN   Implies: square_rhombus(x)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
#
# OPEN   Predicate: atleast-three-congruent-sides(x0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: all-right-angles(x0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# ...
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: square(x0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: simple(x0)
# 'simple1'                                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'concave1'                                                  TRUE (1.0, 1.0)
#
# OPEN   Predicate: right-angled trapezoid(x0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: rhombus(x0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: rectangle(x0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: quadrilateral(x0)
# 'quadrilateral1'                                            TRUE (1.0, 1.0)
# 'complex1'                                                  TRUE (1.0, 1.0)
#
# OPEN   Predicate: parallelogram(x0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: kite(x0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: isosceles trapezoid(x0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: cyclic(x0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: convex(x0)
# 'convex1'                                                   TRUE (1.0, 1.0)
# 'rhombus1'                                                  TRUE (1.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'kite1'                                                     TRUE (1.0, 1.0)
# 'tangential1'                                               TRUE (1.0, 1.0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'parallelogram1'                                            TRUE (1.0, 1.0)
# 'trapezoid1'                                                TRUE (1.0, 1.0)
# 'rectangle1'                                                TRUE (1.0, 1.0)
# 'isosceles trapezoid1'                                      TRUE (1.0, 1.0)
# 'right-angled trapezoid1'                                   TRUE (1.0, 1.0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'cyclic1'                                                   TRUE (1.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: concave(x0)
# 'concave1'                                                  TRUE (1.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'square1'                                                UNKNOWN (0.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: complex(x0)
# 'complex1'                                                  TRUE (1.0, 1.0)
# 'quadrilateral1'                                         UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: bicentric(x0)
# 'bicentric1'                                                TRUE (1.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# '3-sides-equal trapezoid1'                               UNKNOWN (0.0, 1.0)
#
# OPEN   Predicate: 3-sides-equal trapezoid(x0)
# '3-sides-equal trapezoid1'                                  TRUE (1.0, 1.0)
# 'rhombus1'                                               UNKNOWN (0.0, 1.0)
# 'rectangle1'                                             UNKNOWN (0.0, 1.0)
# 'square1'                                                   TRUE (1.0, 1.0)
# 'bicentric1'                                             UNKNOWN (0.0, 1.0)
# 'parallelogram1'                                         UNKNOWN (0.0, 1.0)
# 'isosceles trapezoid1'                                   UNKNOWN (0.0, 1.0)
# 'kite1'                                                  UNKNOWN (0.0, 1.0)
# 'right-angled trapezoid1'                                UNKNOWN (0.0, 1.0)
# 'trapezoid1'                                             UNKNOWN (0.0, 1.0)
# 'simple1'                                                UNKNOWN (0.0, 1.0)
# 'concave1'                                               UNKNOWN (0.0, 1.0)
# 'convex1'                                                UNKNOWN (0.0, 1.0)
# 'tangential1'                                            UNKNOWN (0.0, 1.0)
# 'cyclic1'                                                UNKNOWN (0.0, 1.0)
#
# ***************************************************************************
